# %%
import pandas as pd
df = pd.read_csv("artnet_apr24.csv")
df
# Out:
#                               name                                  title  \
# 0               Thomas Hart Benton                   Keith Farm, Chilmark
# 1                     Dale Nichols                             Farm Scene
# 2                     Milton Avery                                 Siesta
# 3               George L.K. Morris                        Dual Projection
# 4            Ida Ten Eyck O'Keeffe                                  Roots
# ...                            ...                                    ...
# 2985  Attributed to Milard C. Hunt  Circular Gaming Wheel, North Carolina
# 2986                  Purvis Young           People with Halos Above City
# 2987                  Purvis Young    Untitled (Three Saints with Needle)
# 2988        Alexander A. Maldonado                 Museum: Children's Art
# 2989               Rosie Lee Light              Untitled (Birds in Trees)
#
#                                                  medium  \
# 0                                         oil on canvas
# 1                                         oil on canvas
# 2                                         oil on canvas
# 3                                         oil on canvas
# 4                                         oil on canvas
# ...                                                 ...
# 2985                            paint and nails on wood
# 2986                           paint on repurposed wood
# 2987                          enamel on repurposed wood
# 2988  oil, ink and graphite on canvas and original f...
# 2989                         acrylic on repurposed card
#
#                                                    year  \
# 0                                                  1955
# 1                                                  1948
# 2                                             1946-1947
# 3                                                  1950
# 4                                                  1932
# ...                                                 ...
# 2985                                         Circa 1920
# 2986                                               1973
# 2987  Height 96 in.; Width 48 in. / Height 243.8 cm....
# 2988                                               1986
# 2989  Height 21.8 in.; Width 17.8 in. / Height 55.2 ...
#
#                                                    size  \
# 0     Height 21 in.; Width 29 in. / Height 53.3 cm.;...
# 1     Height 30 in.; Width 40 in. / Height 76.2 cm.;...
# 2     Height 30 in.; Width 40 in. / Height 76.2 cm.;...
# 3     Height 30 in.; Width 38 in. / Height 76.2 cm.;...
# 4     Height 20 in.; Width 26 in. / Height 50.8 cm.;...
# ...                                                 ...
# 2985  Width 24 in.; Depth 24 in. / Width 61 cm.; Dep...
# 2986  Height 46 in.; Width 70 in. / Height 116.8 cm....
# 2987  Christie's New York: Friday, January 17, 2020 ...
# 2988  Height 16.4 in.; Width 20.5 in. / Height 41.6 ...
# 2989                                             Signed
#
#                                                    sale  \
# 0     Christie's New York: Thursday, November 18, 20...
# 1     Christie's New York: Thursday, November 18, 20...
# 2     Christie's New York: Thursday, November 18, 20...
# 3     Christie's New York: Thursday, November 18, 20...
# 4     Christie's New York: Thursday, November 18, 20...
# ...                                                 ...
# 2985                                2,000 - 3,000 USD ?
# 2986  Christie's New York: Friday, January 17, 2020 ...
# 2987                               22,500 USD Premium ?
# 2988  Christie's New York: Friday, January 17, 2020 ...
# 2989                                    500 - 800 USD ?
#
#                        sold                     estimate
# 0     4,830,000 USD Premium  2,000,000 - 3,000,000 USD ?
# 1       112,500 USD Premium        50,000 - 70,000 USD ?
# 2                 Bought In  1,500,000 - 2,500,000 USD ?
# 3        56,250 USD Premium        25,000 - 35,000 USD ?
# 4        13,750 USD Premium          4,000 - 6,000 USD ?
# ...                     ...                          ...
# 2985                    NaN            625 USD Premium ?
# 2986     43,750 USD Premium        10,000 - 20,000 USD ?
# 2987                    NaN                          NaN
# 2988        625 USD Premium          1,000 - 2,000 USD ?
# 2989                    NaN            500 USD Premium ?
#
# [2990 rows x 8 columns]

# %%
#clean up arnet artist names to match with names from the artsy API 

df['artist'] = df['name'].str.lower()
df['artist'] = df['artist'].str.replace(" ", "-")
df['artist'] = df['artist'].str.replace("after-", "")
df['artist'] = df['artist'].str.replace(".", "")
df['artist'] = df['artist'].str.replace("é", "e")
df['artist'] = df['artist'].str.replace("è", "e")
df['artist'] = df['artist'].str.replace("è", "e")
df['artist'] = df['artist'].str.replace("&", "and")
df['artist'] = df['artist'].str.replace("í", "i")
df['artist'] = df['artist'].str.replace("attributed-to-", "")
# Out:
# /var/folders/th/rs4zk3q55y3dxsm259ph3h3w0000gn/T/ipykernel_15876/2429864886.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['artist'] = df['artist'].str.replace(".", "")
#                               name                                  title  \
# 0               Thomas Hart Benton                   Keith Farm, Chilmark
# 1                     Dale Nichols                             Farm Scene
# 2                     Milton Avery                                 Siesta
# 3               George L.K. Morris                        Dual Projection
# 4            Ida Ten Eyck O'Keeffe                                  Roots
# ...                            ...                                    ...
# 2985  Attributed to Milard C. Hunt  Circular Gaming Wheel, North Carolina
# 2986                  Purvis Young           People with Halos Above City
# 2987                  Purvis Young    Untitled (Three Saints with Needle)
# 2988        Alexander A. Maldonado                 Museum: Children's Art
# 2989               Rosie Lee Light              Untitled (Birds in Trees)
#
#                                                  medium  \
# 0                                         oil on canvas
# 1                                         oil on canvas
# 2                                         oil on canvas
# 3                                         oil on canvas
# 4                                         oil on canvas
# ...                                                 ...
# 2985                            paint and nails on wood
# 2986                           paint on repurposed wood
# 2987                          enamel on repurposed wood
# 2988  oil, ink and graphite on canvas and original f...
# 2989                         acrylic on repurposed card
#
#                                                    year  \
# 0                                                  1955
# 1                                                  1948
# 2                                             1946-1947
# 3                                                  1950
# 4                                                  1932
# ...                                                 ...
# 2985                                         Circa 1920
# 2986                                               1973
# 2987  Height 96 in.; Width 48 in. / Height 243.8 cm....
# 2988                                               1986
# 2989  Height 21.8 in.; Width 17.8 in. / Height 55.2 ...
#
#                                                    size  \
# 0     Height 21 in.; Width 29 in. / Height 53.3 cm.;...
# 1     Height 30 in.; Width 40 in. / Height 76.2 cm.;...
# 2     Height 30 in.; Width 40 in. / Height 76.2 cm.;...
# 3     Height 30 in.; Width 38 in. / Height 76.2 cm.;...
# 4     Height 20 in.; Width 26 in. / Height 50.8 cm.;...
# ...                                                 ...
# 2985  Width 24 in.; Depth 24 in. / Width 61 cm.; Dep...
# 2986  Height 46 in.; Width 70 in. / Height 116.8 cm....
# 2987  Christie's New York: Friday, January 17, 2020 ...
# 2988  Height 16.4 in.; Width 20.5 in. / Height 41.6 ...
# 2989                                             Signed
#
#                                                    sale  \
# 0     Christie's New York: Thursday, November 18, 20...
# 1     Christie's New York: Thursday, November 18, 20...
# 2     Christie's New York: Thursday, November 18, 20...
# 3     Christie's New York: Thursday, November 18, 20...
# 4     Christie's New York: Thursday, November 18, 20...
# ...                                                 ...
# 2985                                2,000 - 3,000 USD ?
# 2986  Christie's New York: Friday, January 17, 2020 ...
# 2987                               22,500 USD Premium ?
# 2988  Christie's New York: Friday, January 17, 2020 ...
# 2989                                    500 - 800 USD ?
#
#                        sold                     estimate  \
# 0     4,830,000 USD Premium  2,000,000 - 3,000,000 USD ?
# 1       112,500 USD Premium        50,000 - 70,000 USD ?
# 2                 Bought In  1,500,000 - 2,500,000 USD ?
# 3        56,250 USD Premium        25,000 - 35,000 USD ?
# 4        13,750 USD Premium          4,000 - 6,000 USD ?
# ...                     ...                          ...
# 2985                    NaN            625 USD Premium ?
# 2986     43,750 USD Premium        10,000 - 20,000 USD ?
# 2987                    NaN                          NaN
# 2988        625 USD Premium          1,000 - 2,000 USD ?
# 2989                    NaN            500 USD Premium ?
#
#                      artist
# 0        thomas-hart-benton
# 1              dale-nichols
# 2              milton-avery
# 3          george-lk-morris
# 4     ida-ten-eyck-o'keeffe
# ...                     ...
# 2985          milard-c-hunt
# 2986           purvis-young
# 2987           purvis-young
# 2988  alexander-a-maldonado
# 2989        rosie-lee-light
#
# [2990 rows x 9 columns]

# %%
#access Artsy API and generate a token 

import requests
import json

client_id = '083ee8dcdc1bcfa8e7cd'
client_secret = '146159fc83aca327acd54bde4b5f1d14'

# initiate the request to get the token 
r = requests.post("https://api.artsy.net/api/tokens/xapp_token",
                  data={
                      "client_id": client_id,
                      "client_secret": client_secret
                  })

# parse the server response 
j = json.loads(r.text)
j
# extract the token
# Out:
# {'type': 'xapp_token',
#  'token': 'eyJhbGciOiJIUzI1NiJ9.eyJyb2xlcyI6IiIsInN1YmplY3RfYXBwbGljYXRpb24iOiI2MjViMmI3MDdmNDhlMDAwMGUzOGFjNDMiLCJleHAiOjE2NTE2MTEwMTQsImlhdCI6MTY1MTAwNjIxNCwiYXVkIjoiNjI1YjJiNzA3ZjQ4ZTAwMDBlMzhhYzQzIiwiaXNzIjoiR3Jhdml0eSIsImp0aSI6IjYyNjg1YjA2YzlmMTViMDAwYmNlOWQ4MiJ9.IqFLYW6neqtNW82ogPNhDfFivkue-P5icvJQPaTq8MQ',
#  'expires_at': '2022-05-03T20:50:14+00:00',
#  '_links': {}}

# %%
# create a header containing our token 
headers = {"X-Xapp-Token" : 'eyJhbGciOiJIUzI1NiJ9.eyJyb2xlcyI6IiIsInN1YmplY3RfYXBwbGljYXRpb24iOiI2MjViMmI3MDdmNDhlMDAwMGUzOGFjNDMiLCJleHAiOjE2NTE1MjMzNzcsImlhdCI6MTY1MDkxODU3NywiYXVkIjoiNjI1YjJiNzA3ZjQ4ZTAwMDBlMzhhYzQzIiwiaXNzIjoiR3Jhdml0eSIsImp0aSI6IjYyNjcwNGIxYjM2MDI0MDAwZGQ5MzI2OCJ9.m9YuovRLEgjsT_ZjR6RNb4bIboGOqikE4GevB_odX8g'}
# initiate a request with the header 



r = requests.get("https://api.artsy.net/api/artists/a.g.-rizzoli'", headers=headers)

# parse the server response 
j = json.loads(r.text)
j
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/th/rs4zk3q55y3dxsm259ph3h3w0000gn/T/ipykernel_15876/912811244.py in <module>
#       8
#       9 # parse the server response
# ---> 10 j = json.loads(r.text)
#      11 j
#      12
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
#use the names from our artnet database to find gender and nationality info using the artsy API 

import time 

case_list = []

errors = []
for name in df['artist'].unique():
        print(name)
        try:
            url = "https://api.artsy.net/api/artists/" + name  #name is the name of the artist we're looking for 
            url = f"{url}"  #puts quotes aruond url 
            print(url)
            r = requests.get(url, headers=headers)
            j = json.loads(r.text)
            
            
            artist = j['slug']
       

            case = {'artist': j['slug'], 'gender': j['gender'], 'nationality': j['nationality'], 'birthday': j['birthday'], 'hometown': j['hometown']}
            case_list.append(case)
            time.sleep(2)
        except:
            print("error", name)
            errors.append(name)
# Out:
# thomas-hart-benton
# https://api.artsy.net/api/artists/thomas-hart-benton
# dale-nichols
# https://api.artsy.net/api/artists/dale-nichols
# milton-avery
# https://api.artsy.net/api/artists/milton-avery
# george-lk-morris
# https://api.artsy.net/api/artists/george-lk-morris
# error george-lk-morris
# ida-ten-eyck-o'keeffe
# https://api.artsy.net/api/artists/ida-ten-eyck-o'keeffe
# error ida-ten-eyck-o'keeffe
# stanton-macdonald-wright
# https://api.artsy.net/api/artists/stanton-macdonald-wright
# fairfield-porter
# https://api.artsy.net/api/artists/fairfield-porter
# wolf-kahn
# https://api.artsy.net/api/artists/wolf-kahn
# marsden-hartley
# https://api.artsy.net/api/artists/marsden-hartley
# george-bellows
# https://api.artsy.net/api/artists/george-bellows
# john-leslie-breck
# https://api.artsy.net/api/artists/john-leslie-breck
# frederick-carl-frieseke
# https://api.artsy.net/api/artists/frederick-carl-frieseke
# paul-cadmus
# https://api.artsy.net/api/artists/paul-cadmus
# maxfield-parrish
# https://api.artsy.net/api/artists/maxfield-parrish
# henrietta-shore
# https://api.artsy.net/api/artists/henrietta-shore
# reginald-marsh
# https://api.artsy.net/api/artists/reginald-marsh
# walt-kuhn
# https://api.artsy.net/api/artists/walt-kuhn
# maurice-prendergast
# https://api.artsy.net/api/artists/maurice-prendergast
# john-marin
# https://api.artsy.net/api/artists/john-marin
# stuart-davis
# https://api.artsy.net/api/artists/stuart-davis
# louis-ritman
# https://api.artsy.net/api/artists/louis-ritman
# ernest-lawson
# https://api.artsy.net/api/artists/ernest-lawson
# guy-carleton-wiggins
# https://api.artsy.net/api/artists/guy-carleton-wiggins
# john-marshall-gamble
# https://api.artsy.net/api/artists/john-marshall-gamble
# william-merritt-chase
# https://api.artsy.net/api/artists/william-merritt-chase
# leon-kelly
# https://api.artsy.net/api/artists/leon-kelly
# nc-wyeth
# https://api.artsy.net/api/artists/nc-wyeth
# robert-henri
# https://api.artsy.net/api/artists/robert-henri
# colin-campbell-cooper
# https://api.artsy.net/api/artists/colin-campbell-cooper
# porfirio-salinas
# https://api.artsy.net/api/artists/porfirio-salinas
# oscar-florianus-bluemner
# https://api.artsy.net/api/artists/oscar-florianus-bluemner
# error oscar-florianus-bluemner
# grandma-moses
# https://api.artsy.net/api/artists/grandma-moses
# george-l-noyes
# https://api.artsy.net/api/artists/george-l-noyes
# arthur-dove
# https://api.artsy.net/api/artists/arthur-dove
# george-copeland-ault
# https://api.artsy.net/api/artists/george-copeland-ault
# henriette-wyeth
# https://api.artsy.net/api/artists/henriette-wyeth
# georges-braque
# https://api.artsy.net/api/artists/georges-braque
# alfred-sisley
# https://api.artsy.net/api/artists/alfred-sisley
# pierre-auguste-renoir
# https://api.artsy.net/api/artists/pierre-auguste-renoir
# francis-picabia
# https://api.artsy.net/api/artists/francis-picabia
# gustave-loiseau
# https://api.artsy.net/api/artists/gustave-loiseau
# marie-laurencin
# https://api.artsy.net/api/artists/marie-laurencin
# maurice-utrillo
# https://api.artsy.net/api/artists/maurice-utrillo
# jean-dufy
# https://api.artsy.net/api/artists/jean-dufy
# jean-pierre-cassigneul
# https://api.artsy.net/api/artists/jean-pierre-cassigneul
# louis-valtat
# https://api.artsy.net/api/artists/louis-valtat
# max-pechstein
# https://api.artsy.net/api/artists/max-pechstein
# marc-chagall
# https://api.artsy.net/api/artists/marc-chagall
# georges-rouault
# https://api.artsy.net/api/artists/georges-rouault
# fernand-leger
# https://api.artsy.net/api/artists/fernand-leger
# raoul-dufy
# https://api.artsy.net/api/artists/raoul-dufy
# andre-masson
# https://api.artsy.net/api/artists/andre-masson
# maximilien-luce
# https://api.artsy.net/api/artists/maximilien-luce
# chaim-soutine
# https://api.artsy.net/api/artists/chaim-soutine
# alberto-giacometti
# https://api.artsy.net/api/artists/alberto-giacometti
# armand-guillaumin
# https://api.artsy.net/api/artists/armand-guillaumin
# max-ernst
# https://api.artsy.net/api/artists/max-ernst
# henri-edmond-cross
# https://api.artsy.net/api/artists/henri-edmond-cross
# pierre-bonnard
# https://api.artsy.net/api/artists/pierre-bonnard
# pablo-picasso
# https://api.artsy.net/api/artists/pablo-picasso
# edouard-vuillard
# https://api.artsy.net/api/artists/edouard-vuillard
# camille-pissarro
# https://api.artsy.net/api/artists/camille-pissarro
# jean-metzinger
# https://api.artsy.net/api/artists/jean-metzinger
# paul-serusier
# https://api.artsy.net/api/artists/paul-serusier
# maurice-de-vlaminck
# https://api.artsy.net/api/artists/maurice-de-vlaminck
# maurice-denis
# https://api.artsy.net/api/artists/maurice-denis
# alexej-von-jawlensky
# https://api.artsy.net/api/artists/alexej-von-jawlensky
# pierre-eugene-montezin
# https://api.artsy.net/api/artists/pierre-eugene-montezin
# georges-d'-espagnat
# https://api.artsy.net/api/artists/georges-d'-espagnat
# error georges-d'-espagnat
# henri-lebasque
# https://api.artsy.net/api/artists/henri-lebasque
# henri-charles-manguin
# https://api.artsy.net/api/artists/henri-charles-manguin
# kurt-schwitters
# https://api.artsy.net/api/artists/kurt-schwitters
# henry-moret
# https://api.artsy.net/api/artists/henry-moret
# andre-lhote
# https://api.artsy.net/api/artists/andre-lhote
# marino-marini
# https://api.artsy.net/api/artists/marino-marini
# bernard-buffet
# https://api.artsy.net/api/artists/bernard-buffet
# henri-le-sidaner
# https://api.artsy.net/api/artists/henri-le-sidaner
# odilon-redon
# https://api.artsy.net/api/artists/odilon-redon
# henri-matisse
# https://api.artsy.net/api/artists/henri-matisse
# eugene-boudin
# https://api.artsy.net/api/artists/eugene-boudin
# moïse-kisling
# https://api.artsy.net/api/artists/moïse-kisling
# error moïse-kisling
# henri-jean-guillaume-martin
# https://api.artsy.net/api/artists/henri-jean-guillaume-martin
# error henri-jean-guillaume-martin
# leo-gausson
# https://api.artsy.net/api/artists/leo-gausson
# joan-miró
# https://api.artsy.net/api/artists/joan-miró
# error joan-miró
# gustave-cariot
# https://api.artsy.net/api/artists/gustave-cariot
# suzanne-valadon
# https://api.artsy.net/api/artists/suzanne-valadon
# andre-brasilier
# https://api.artsy.net/api/artists/andre-brasilier
# andre-derain
# https://api.artsy.net/api/artists/andre-derain
# cecily-brown
# https://api.artsy.net/api/artists/cecily-brown
# keith-haring
# https://api.artsy.net/api/artists/keith-haring
# alice-neel
# https://api.artsy.net/api/artists/alice-neel
# richard-prince
# https://api.artsy.net/api/artists/richard-prince
# andy-warhol
# https://api.artsy.net/api/artists/andy-warhol
# sean-scully
# https://api.artsy.net/api/artists/sean-scully
# theodoros-stamos
# https://api.artsy.net/api/artists/theodoros-stamos
# jean-dubuffet
# https://api.artsy.net/api/artists/jean-dubuffet
# sam-francis
# https://api.artsy.net/api/artists/sam-francis
# helen-frankenthaler
# https://api.artsy.net/api/artists/helen-frankenthaler
# james-rosenquist
# https://api.artsy.net/api/artists/james-rosenquist
# mark-rothko
# https://api.artsy.net/api/artists/mark-rothko
# adolph-gottlieb
# https://api.artsy.net/api/artists/adolph-gottlieb
# billy-al-bengston
# https://api.artsy.net/api/artists/billy-al-bengston
# kenneth-noland
# https://api.artsy.net/api/artists/kenneth-noland
# daniel-richter
# https://api.artsy.net/api/artists/daniel-richter
# matthew-barney
# https://api.artsy.net/api/artists/matthew-barney
# jean-paul-riopelle
# https://api.artsy.net/api/artists/jean-paul-riopelle
# robert-mapplethorpe
# https://api.artsy.net/api/artists/robert-mapplethorpe
# david-wojnarowicz
# https://api.artsy.net/api/artists/david-wojnarowicz
# david-salle
# https://api.artsy.net/api/artists/david-salle
# richard-pettibone
# https://api.artsy.net/api/artists/richard-pettibone
# ugo-rondinone
# https://api.artsy.net/api/artists/ugo-rondinone
# leon-polk-smith
# https://api.artsy.net/api/artists/leon-polk-smith
# george-condo
# https://api.artsy.net/api/artists/george-condo
# matthew-wong
# https://api.artsy.net/api/artists/matthew-wong
# cindy-sherman
# https://api.artsy.net/api/artists/cindy-sherman
# philip-guston
# https://api.artsy.net/api/artists/philip-guston
# al-held
# https://api.artsy.net/api/artists/al-held
# josef-albers
# https://api.artsy.net/api/artists/josef-albers
# gerhard-richter
# https://api.artsy.net/api/artists/gerhard-richter
# alfred-jensen
# https://api.artsy.net/api/artists/alfred-jensen
# tom-wesselmann
# https://api.artsy.net/api/artists/tom-wesselmann
# mary-weatherford
# https://api.artsy.net/api/artists/mary-weatherford
# sam-gilliam
# https://api.artsy.net/api/artists/sam-gilliam
# hans-hofmann
# https://api.artsy.net/api/artists/hans-hofmann
# norman-bluhm
# https://api.artsy.net/api/artists/norman-bluhm
# rudolf-stingel
# https://api.artsy.net/api/artists/rudolf-stingel
# christopher-wool
# https://api.artsy.net/api/artists/christopher-wool
# kara-walker
# https://api.artsy.net/api/artists/kara-walker
# tseng-kwong-chi
# https://api.artsy.net/api/artists/tseng-kwong-chi
# kenny-scharf
# https://api.artsy.net/api/artists/kenny-scharf
# john-baldessari
# https://api.artsy.net/api/artists/john-baldessari
# alex-katz
# https://api.artsy.net/api/artists/alex-katz
# gary-hume
# https://api.artsy.net/api/artists/gary-hume
# hiroshi-sugimoto
# https://api.artsy.net/api/artists/hiroshi-sugimoto
# jules-olitski
# https://api.artsy.net/api/artists/jules-olitski
# kehinde-wiley
# https://api.artsy.net/api/artists/kehinde-wiley
# david-smith
# https://api.artsy.net/api/artists/david-smith
# romare-bearden
# https://api.artsy.net/api/artists/romare-bearden
# jim-nutt
# https://api.artsy.net/api/artists/jim-nutt
# robert-mangold
# https://api.artsy.net/api/artists/robert-mangold
# albert-oehlen
# https://api.artsy.net/api/artists/albert-oehlen
# jacqueline-humphries
# https://api.artsy.net/api/artists/jacqueline-humphries
# rashid-johnson
# https://api.artsy.net/api/artists/rashid-johnson
# lucas-samaras
# https://api.artsy.net/api/artists/lucas-samaras
# mary-corse
# https://api.artsy.net/api/artists/mary-corse
# ed-clark
# https://api.artsy.net/api/artists/ed-clark
# francis-alÿs
# https://api.artsy.net/api/artists/francis-alÿs
# error francis-alÿs
# grace-hartigan
# https://api.artsy.net/api/artists/grace-hartigan
# hernan-bas
# https://api.artsy.net/api/artists/hernan-bas
# glenn-ligon
# https://api.artsy.net/api/artists/glenn-ligon
# ann-craven
# https://api.artsy.net/api/artists/ann-craven
# anselm-kiefer
# https://api.artsy.net/api/artists/anselm-kiefer
# joyce-pensato
# https://api.artsy.net/api/artists/joyce-pensato
# yoshitomo-nara
# https://api.artsy.net/api/artists/yoshitomo-nara
# takashi-murakami
# https://api.artsy.net/api/artists/takashi-murakami
# julian-schnabel
# https://api.artsy.net/api/artists/julian-schnabel
# jeff-koons
# https://api.artsy.net/api/artists/jeff-koons
# richard-artschwager
# https://api.artsy.net/api/artists/richard-artschwager
# deborah-roberts
# https://api.artsy.net/api/artists/deborah-roberts
# jamian-juliano-villani
# https://api.artsy.net/api/artists/jamian-juliano-villani
# loie-hollowell
# https://api.artsy.net/api/artists/loie-hollowell
# emily-mae-smith
# https://api.artsy.net/api/artists/emily-mae-smith
# jonas-wood
# https://api.artsy.net/api/artists/jonas-wood
# allison-zuckerman
# https://api.artsy.net/api/artists/allison-zuckerman
# oscar-murillo
# https://api.artsy.net/api/artists/oscar-murillo
# claire-tabouret
# https://api.artsy.net/api/artists/claire-tabouret
# alex-hubbard
# https://api.artsy.net/api/artists/alex-hubbard
# israel-lund
# https://api.artsy.net/api/artists/israel-lund
# marley-freeman
# https://api.artsy.net/api/artists/marley-freeman
# joe-bradley
# https://api.artsy.net/api/artists/joe-bradley
# nick-cave
# https://api.artsy.net/api/artists/nick-cave
# wade-guyton
# https://api.artsy.net/api/artists/wade-guyton
# theaster-gates
# https://api.artsy.net/api/artists/theaster-gates
# ernie-barnes
# https://api.artsy.net/api/artists/ernie-barnes
# error ernie-barnes
# eddie-martinez
# https://api.artsy.net/api/artists/eddie-martinez
# trevor-paglen
# https://api.artsy.net/api/artists/trevor-paglen
# lucy-dodd
# https://api.artsy.net/api/artists/lucy-dodd
# julie-curtiss
# https://api.artsy.net/api/artists/julie-curtiss
# sarah-sze
# https://api.artsy.net/api/artists/sarah-sze
# amy-sillman
# https://api.artsy.net/api/artists/amy-sillman
# danielle-orchard
# https://api.artsy.net/api/artists/danielle-orchard
# mamma-andersson
# https://api.artsy.net/api/artists/mamma-andersson
# kaws
# https://api.artsy.net/api/artists/kaws
# aaron-garber-maikovska
# https://api.artsy.net/api/artists/aaron-garber-maikovska
# jörg-immendorff
# https://api.artsy.net/api/artists/jörg-immendorff
# error jörg-immendorff
# oluwole-omofemi
# https://api.artsy.net/api/artists/oluwole-omofemi
# genieve-figgis
# https://api.artsy.net/api/artists/genieve-figgis
# josh-smith
# https://api.artsy.net/api/artists/josh-smith
# hilary-pecis
# https://api.artsy.net/api/artists/hilary-pecis
# issy-wood
# https://api.artsy.net/api/artists/issy-wood
# harold-ancart
# https://api.artsy.net/api/artists/harold-ancart
# noah-davis
# https://api.artsy.net/api/artists/noah-davis
# günther-förg
# https://api.artsy.net/api/artists/günther-förg
# error günther-förg
# jammie-holmes
# https://api.artsy.net/api/artists/jammie-holmes
# jonathan-lyndon-chase
# https://api.artsy.net/api/artists/jonathan-lyndon-chase
# roberto-matta
# https://api.artsy.net/api/artists/roberto-matta
# cheyney-thompson
# https://api.artsy.net/api/artists/cheyney-thompson
# shara-hughes
# https://api.artsy.net/api/artists/shara-hughes
# jennifer-guidi
# https://api.artsy.net/api/artists/jennifer-guidi
# felix-gonzalez-torres
# https://api.artsy.net/api/artists/felix-gonzalez-torres
# bosco-sodi
# https://api.artsy.net/api/artists/bosco-sodi
# ellsworth-kelly
# https://api.artsy.net/api/artists/ellsworth-kelly
# claude-monet
# https://api.artsy.net/api/artists/claude-monet
# vincent-van-gogh
# https://api.artsy.net/api/artists/vincent-van-gogh
# kees-van-dongen
# https://api.artsy.net/api/artists/kees-van-dongen
# childe-hassam
# https://api.artsy.net/api/artists/childe-hassam
# paul-cezanne
# https://api.artsy.net/api/artists/paul-cezanne
# james-abbott-mcneill-whistler
# https://api.artsy.net/api/artists/james-abbott-mcneill-whistler
# david-hockney
# https://api.artsy.net/api/artists/david-hockney
# wifredo-lam
# https://api.artsy.net/api/artists/wifredo-lam
# arshile-gorky
# https://api.artsy.net/api/artists/arshile-gorky
# richard-diebenkorn
# https://api.artsy.net/api/artists/richard-diebenkorn
# robert-rauschenberg
# https://api.artsy.net/api/artists/robert-rauschenberg
# salvatore-scarpitta
# https://api.artsy.net/api/artists/salvatore-scarpitta
# balthus
# https://api.artsy.net/api/artists/balthus
# hugh-henry-breckenridge
# https://api.artsy.net/api/artists/hugh-henry-breckenridge
# gustave-caillebotte
# https://api.artsy.net/api/artists/gustave-caillebotte
# ed-ruscha
# https://api.artsy.net/api/artists/ed-ruscha
# edward-hopper
# https://api.artsy.net/api/artists/edward-hopper
# cy-twombly
# https://api.artsy.net/api/artists/cy-twombly
# joan-mitchell
# https://api.artsy.net/api/artists/joan-mitchell
# giorgio-morandi
# https://api.artsy.net/api/artists/giorgio-morandi
# berthe-morisot
# https://api.artsy.net/api/artists/berthe-morisot
# henri-de-toulouse-lautrec
# https://api.artsy.net/api/artists/henri-de-toulouse-lautrec
# willem-de-kooning
# https://api.artsy.net/api/artists/willem-de-kooning
# jacob-lawrence
# https://api.artsy.net/api/artists/jacob-lawrence
# kazuo-shiraga
# https://api.artsy.net/api/artists/kazuo-shiraga
# elizabeth-peyton
# https://api.artsy.net/api/artists/elizabeth-peyton
# jean-michel-basquiat
# https://api.artsy.net/api/artists/jean-michel-basquiat
# mark-bradford
# https://api.artsy.net/api/artists/mark-bradford
# barbara-kruger
# https://api.artsy.net/api/artists/barbara-kruger
# peter-doig
# https://api.artsy.net/api/artists/peter-doig
# damien-hirst
# https://api.artsy.net/api/artists/damien-hirst
# georg-baselitz
# https://api.artsy.net/api/artists/georg-baselitz
# stanley-whitney
# https://api.artsy.net/api/artists/stanley-whitney
# jack-whitten
# https://api.artsy.net/api/artists/jack-whitten
# dana-schutz
# https://api.artsy.net/api/artists/dana-schutz
# mickalene-thomas
# https://api.artsy.net/api/artists/mickalene-thomas
# cheng-xinyi
# https://api.artsy.net/api/artists/cheng-xinyi
# error cheng-xinyi
# nicolas-party
# https://api.artsy.net/api/artists/nicolas-party
# yan-pei-ming
# https://api.artsy.net/api/artists/yan-pei-ming
# banksy
# https://api.artsy.net/api/artists/banksy
# el-anatsui
# https://api.artsy.net/api/artists/el-anatsui
# workshop-of-jan-(joannes-sinapius)-mostaert
# https://api.artsy.net/api/artists/workshop-of-jan-(joannes-sinapius)-mostaert
# error workshop-of-jan-(joannes-sinapius)-mostaert
# lucas-van-valkenborch
# https://api.artsy.net/api/artists/lucas-van-valkenborch
# error lucas-van-valkenborch
# lorenzo-costa
# https://api.artsy.net/api/artists/lorenzo-costa
# angelika-kauffmann
# https://api.artsy.net/api/artists/angelika-kauffmann
# error angelika-kauffmann
# pietro-da-cortona
# https://api.artsy.net/api/artists/pietro-da-cortona
# error pietro-da-cortona
# philips-wouwerman
# https://api.artsy.net/api/artists/philips-wouwerman
# jacob-symonsz-pynas
# https://api.artsy.net/api/artists/jacob-symonsz-pynas
# error jacob-symonsz-pynas
# gerrit-lundens
# https://api.artsy.net/api/artists/gerrit-lundens
# error gerrit-lundens
# circle-of-frans-floris-the-elder
# https://api.artsy.net/api/artists/circle-of-frans-floris-the-elder
# error circle-of-frans-floris-the-elder
# simon-hardime
# https://api.artsy.net/api/artists/simon-hardime
# error simon-hardime
# theodoor-rombouts
# https://api.artsy.net/api/artists/theodoor-rombouts
# error theodoor-rombouts
# jacob-adriaensz-backer
# https://api.artsy.net/api/artists/jacob-adriaensz-backer
# corneille-de-lyon
# https://api.artsy.net/api/artists/corneille-de-lyon
# error corneille-de-lyon
# marten-van-cleve-the-elder
# https://api.artsy.net/api/artists/marten-van-cleve-the-elder
# error marten-van-cleve-the-elder
# mario-nuzzi
# https://api.artsy.net/api/artists/mario-nuzzi
# error mario-nuzzi
# nicolaes-maes
# https://api.artsy.net/api/artists/nicolaes-maes
# follower-of-canaletto
# https://api.artsy.net/api/artists/follower-of-canaletto
# error follower-of-canaletto
# rachel-ruysch
# https://api.artsy.net/api/artists/rachel-ruysch
# george-romney
# https://api.artsy.net/api/artists/george-romney
# henry-fuseli
# https://api.artsy.net/api/artists/henry-fuseli
# tommaso-ruiz
# https://api.artsy.net/api/artists/tommaso-ruiz
# error tommaso-ruiz
# circle-of-jan-van-scorel
# https://api.artsy.net/api/artists/circle-of-jan-van-scorel
# error circle-of-jan-van-scorel
# master-of-the-misericordia
# https://api.artsy.net/api/artists/master-of-the-misericordia
# error master-of-the-misericordia
# spagna-(giovanni-lo-spagnolo)
# https://api.artsy.net/api/artists/spagna-(giovanni-lo-spagnolo)
# error spagna-(giovanni-lo-spagnolo)
# jacob-jordaens
# https://api.artsy.net/api/artists/jacob-jordaens
# karel-dujardin
# https://api.artsy.net/api/artists/karel-dujardin
# studio-of-giovanni-bilivert
# https://api.artsy.net/api/artists/studio-of-giovanni-bilivert
# error studio-of-giovanni-bilivert
# studio-of-frans-floris-the-elder
# https://api.artsy.net/api/artists/studio-of-frans-floris-the-elder
# error studio-of-frans-floris-the-elder
# circle-of-jan-brueghel-the-elder
# https://api.artsy.net/api/artists/circle-of-jan-brueghel-the-elder
# error circle-of-jan-brueghel-the-elder
# jean-joseph-xavier-bidauld
# https://api.artsy.net/api/artists/jean-joseph-xavier-bidauld
# gabriel-metsu
# https://api.artsy.net/api/artists/gabriel-metsu
# jan-cossiers
# https://api.artsy.net/api/artists/jan-cossiers
# studio-of-giovanni-paolo-panini
# https://api.artsy.net/api/artists/studio-of-giovanni-paolo-panini
# jan-josefsz-van-goyen
# https://api.artsy.net/api/artists/jan-josefsz-van-goyen
# error jan-josefsz-van-goyen
# otto-octavius-van-veen
# https://api.artsy.net/api/artists/otto-octavius-van-veen
# error otto-octavius-van-veen
# sir-william-beechey
# https://api.artsy.net/api/artists/sir-william-beechey
# lucas-cranach-the-younger
# https://api.artsy.net/api/artists/lucas-cranach-the-younger
# peter-(petrus)-snyers
# https://api.artsy.net/api/artists/peter-(petrus)-snyers
# error peter-(petrus)-snyers
# giovanni-andrea-sirani
# https://api.artsy.net/api/artists/giovanni-andrea-sirani
# error giovanni-andrea-sirani
# pietro-longhi
# https://api.artsy.net/api/artists/pietro-longhi
# joseph-wright-(of-derby)
# https://api.artsy.net/api/artists/joseph-wright-(of-derby)
# error joseph-wright-(of-derby)
# jacques-laurent-agasse
# https://api.artsy.net/api/artists/jacques-laurent-agasse
# jean-baptiste-pater
# https://api.artsy.net/api/artists/jean-baptiste-pater
# error jean-baptiste-pater
# cesare-dandini
# https://api.artsy.net/api/artists/cesare-dandini
# françois-pascal-simon-gerard
# https://api.artsy.net/api/artists/françois-pascal-simon-gerard
# error françois-pascal-simon-gerard
# louis-nicolas-van-blarenberghe
# https://api.artsy.net/api/artists/louis-nicolas-van-blarenberghe
# error louis-nicolas-van-blarenberghe
# nicolaes-eliasz-pickenoy
# https://api.artsy.net/api/artists/nicolaes-eliasz-pickenoy
# studio-of-david-teniers-the-younger
# https://api.artsy.net/api/artists/studio-of-david-teniers-the-younger
# error studio-of-david-teniers-the-younger
# adriaen-van-stalbemt
# https://api.artsy.net/api/artists/adriaen-van-stalbemt
# john-hoppner
# https://api.artsy.net/api/artists/john-hoppner
# simon-vouet
# https://api.artsy.net/api/artists/simon-vouet
# annibale-carracci
# https://api.artsy.net/api/artists/annibale-carracci
# giuliano-bugiardini
# https://api.artsy.net/api/artists/giuliano-bugiardini
# barent-fabritius
# https://api.artsy.net/api/artists/barent-fabritius
# error barent-fabritius
# adriaen-jansz-van-ostade
# https://api.artsy.net/api/artists/adriaen-jansz-van-ostade
# error adriaen-jansz-van-ostade
# abraham-willemsens
# https://api.artsy.net/api/artists/abraham-willemsens
# nicolas-lancret
# https://api.artsy.net/api/artists/nicolas-lancret
# roelandt-savery
# https://api.artsy.net/api/artists/roelandt-savery
# luca-giordano
# https://api.artsy.net/api/artists/luca-giordano
# giulio-cesare-procaccini
# https://api.artsy.net/api/artists/giulio-cesare-procaccini
# jean-marc-nattier
# https://api.artsy.net/api/artists/jean-marc-nattier
# circle-of-william-hogarth
# https://api.artsy.net/api/artists/circle-of-william-hogarth
# andrea-appiani-the-elder
# https://api.artsy.net/api/artists/andrea-appiani-the-elder
# error andrea-appiani-the-elder
# sofonisba-anguissola
# https://api.artsy.net/api/artists/sofonisba-anguissola
# giovanni-francesco-(il-nosadella)-bezzi
# https://api.artsy.net/api/artists/giovanni-francesco-(il-nosadella)-bezzi
# error giovanni-francesco-(il-nosadella)-bezzi
# esaias-van-de-velde-the-elder
# https://api.artsy.net/api/artists/esaias-van-de-velde-the-elder
# error esaias-van-de-velde-the-elder
# anton-maria-vassallo
# https://api.artsy.net/api/artists/anton-maria-vassallo
# error anton-maria-vassallo
# carlo-caliari
# https://api.artsy.net/api/artists/carlo-caliari
# error carlo-caliari
# egbert-van-heemskerck-the-elder
# https://api.artsy.net/api/artists/egbert-van-heemskerck-the-elder
# error egbert-van-heemskerck-the-elder
# british-school-(17/18)
# https://api.artsy.net/api/artists/british-school-(17/18)
# error british-school-(17/18)
# italian-school-(18)
# https://api.artsy.net/api/artists/italian-school-(18)
# error italian-school-(18)
# george-(sir)-chalmers
# https://api.artsy.net/api/artists/george-(sir)-chalmers
# error george-(sir)-chalmers
# gijsbrecht-leytens
# https://api.artsy.net/api/artists/gijsbrecht-leytens
# giovanni-battista-salvi-(il-sassoferrato)
# https://api.artsy.net/api/artists/giovanni-battista-salvi-(il-sassoferrato)
# error giovanni-battista-salvi-(il-sassoferrato)
# pierre-duval-lecamus
# https://api.artsy.net/api/artists/pierre-duval-lecamus
# error pierre-duval-lecamus
# spanish-school-(16)
# https://api.artsy.net/api/artists/spanish-school-(16)
# error spanish-school-(16)
# italian-school-northern-(16)
# https://api.artsy.net/api/artists/italian-school-northern-(16)
# error italian-school-northern-(16)
# anthony-van-dyck
# https://api.artsy.net/api/artists/anthony-van-dyck
# maerten-jacobsz-van-heemskerck
# https://api.artsy.net/api/artists/maerten-jacobsz-van-heemskerck
# error maerten-jacobsz-van-heemskerck
# pieter-brueghel-the-younger
# https://api.artsy.net/api/artists/pieter-brueghel-the-younger
# domenico-parodi
# https://api.artsy.net/api/artists/domenico-parodi
# error domenico-parodi
# joseph-tassy
# https://api.artsy.net/api/artists/joseph-tassy
# error joseph-tassy
# follower-of-leonardo-da-vinci
# https://api.artsy.net/api/artists/follower-of-leonardo-da-vinci
# titian
# https://api.artsy.net/api/artists/titian
# jakob-isaakszoon-van-ruysdael
# https://api.artsy.net/api/artists/jakob-isaakszoon-van-ruysdael
# error jakob-isaakszoon-van-ruysdael
# giuseppe-bernardino-bison
# https://api.artsy.net/api/artists/giuseppe-bernardino-bison
# studio-of-hyacinthe-rigaud
# https://api.artsy.net/api/artists/studio-of-hyacinthe-rigaud
# error studio-of-hyacinthe-rigaud
# nicolas-de-largilliere
# https://api.artsy.net/api/artists/nicolas-de-largilliere
# error nicolas-de-largilliere
# pieter-bout-and-hendrick-de-meijer
# https://api.artsy.net/api/artists/pieter-bout-and-hendrick-de-meijer
# error pieter-bout-and-hendrick-de-meijer
# master-of-fossa
# https://api.artsy.net/api/artists/master-of-fossa
# error master-of-fossa
# italian-school-florentine-(14)
# https://api.artsy.net/api/artists/italian-school-florentine-(14)
# error italian-school-florentine-(14)
# louis-gauffier
# https://api.artsy.net/api/artists/louis-gauffier
# error louis-gauffier
# giacomo-da-recanati
# https://api.artsy.net/api/artists/giacomo-da-recanati
# error giacomo-da-recanati
# master-of-the-wallraf-triptych
# https://api.artsy.net/api/artists/master-of-the-wallraf-triptych
# error master-of-the-wallraf-triptych
# master-of-the-dijon-madonna
# https://api.artsy.net/api/artists/master-of-the-dijon-madonna
# error master-of-the-dijon-madonna
# ambrogio-de-predis
# https://api.artsy.net/api/artists/ambrogio-de-predis
# jean-jacques-françois-le-barbier
# https://api.artsy.net/api/artists/jean-jacques-françois-le-barbier
# error jean-jacques-françois-le-barbier
# domenico-tintoretto
# https://api.artsy.net/api/artists/domenico-tintoretto
# error domenico-tintoretto
# anonymous-italian-(18)
# https://api.artsy.net/api/artists/anonymous-italian-(18)
# error anonymous-italian-(18)
# master-of-hartford
# https://api.artsy.net/api/artists/master-of-hartford
# error master-of-hartford
# dosso-dossi
# https://api.artsy.net/api/artists/dosso-dossi
# italian-school-roman-(18)
# https://api.artsy.net/api/artists/italian-school-roman-(18)
# error italian-school-roman-(18)
# francesco-guardi-and-giovanni-antonio-guardi
# https://api.artsy.net/api/artists/francesco-guardi-and-giovanni-antonio-guardi
# error francesco-guardi-and-giovanni-antonio-guardi
# studio-of-peter-paul-rubens
# https://api.artsy.net/api/artists/studio-of-peter-paul-rubens
# error studio-of-peter-paul-rubens
# master-of-sant'ivo
# https://api.artsy.net/api/artists/master-of-sant'ivo
# error master-of-sant'ivo
# santi-di-tito
# https://api.artsy.net/api/artists/santi-di-tito
# alessandro-allori-and-giovanni-maria-butteri
# https://api.artsy.net/api/artists/alessandro-allori-and-giovanni-maria-butteri
# error alessandro-allori-and-giovanni-maria-butteri
# anne-louis-girodet-de-roucy-trioson
# https://api.artsy.net/api/artists/anne-louis-girodet-de-roucy-trioson
# error anne-louis-girodet-de-roucy-trioson
# lavinia-fontana
# https://api.artsy.net/api/artists/lavinia-fontana
# vilhelm-hammershøi
# https://api.artsy.net/api/artists/vilhelm-hammershøi
# error vilhelm-hammershøi
# jean-françois-millet
# https://api.artsy.net/api/artists/jean-françois-millet
# error jean-françois-millet
# carl-vilhelm-holsøe
# https://api.artsy.net/api/artists/carl-vilhelm-holsøe
# error carl-vilhelm-holsøe
# william-adolphe-bouguereau
# https://api.artsy.net/api/artists/william-adolphe-bouguereau
# franz-xaver-winterhalter
# https://api.artsy.net/api/artists/franz-xaver-winterhalter
# frederick-arthur-bridgman
# https://api.artsy.net/api/artists/frederick-arthur-bridgman
# rosa-bonheur
# https://api.artsy.net/api/artists/rosa-bonheur
# error rosa-bonheur
# gustave-courbet
# https://api.artsy.net/api/artists/gustave-courbet
# sir-alfred-munnings
# https://api.artsy.net/api/artists/sir-alfred-munnings
# error sir-alfred-munnings
# leon-augustin-l'hermitte
# https://api.artsy.net/api/artists/leon-augustin-l'hermitte
# error leon-augustin-l'hermitte
# herbert-james-draper
# https://api.artsy.net/api/artists/herbert-james-draper
# error herbert-james-draper
# dame-laura-knight
# https://api.artsy.net/api/artists/dame-laura-knight
# vittorio-matteo-corcos
# https://api.artsy.net/api/artists/vittorio-matteo-corcos
# error vittorio-matteo-corcos
# gustav-bauernfeind
# https://api.artsy.net/api/artists/gustav-bauernfeind
# john-atkinson-grimshaw
# https://api.artsy.net/api/artists/john-atkinson-grimshaw
# giovanni-segantini
# https://api.artsy.net/api/artists/giovanni-segantini
# jean-françois-raffaëlli
# https://api.artsy.net/api/artists/jean-françois-raffaëlli
# error jean-françois-raffaëlli
# cornelis-springer
# https://api.artsy.net/api/artists/cornelis-springer
# john-william-godward
# https://api.artsy.net/api/artists/john-william-godward
# peder-severin-krøyer
# https://api.artsy.net/api/artists/peder-severin-krøyer
# error peder-severin-krøyer
# jean-baptiste-camille-corot
# https://api.artsy.net/api/artists/jean-baptiste-camille-corot
# julius-leblanc-stewart
# https://api.artsy.net/api/artists/julius-leblanc-stewart
# frank-dicksee
# https://api.artsy.net/api/artists/frank-dicksee
# error frank-dicksee
# andre-kertesz
# https://api.artsy.net/api/artists/andre-kertesz
# brassaï
# https://api.artsy.net/api/artists/brassaï
# error brassaï
# robert-frank
# https://api.artsy.net/api/artists/robert-frank
# vik-muniz
# https://api.artsy.net/api/artists/vik-muniz
# peter-hujar
# https://api.artsy.net/api/artists/peter-hujar
# jenny-holzer
# https://api.artsy.net/api/artists/jenny-holzer
# james-welling
# https://api.artsy.net/api/artists/james-welling
# aaron-siskind
# https://api.artsy.net/api/artists/aaron-siskind
# thomas-ruff
# https://api.artsy.net/api/artists/thomas-ruff
# adam-fuss
# https://api.artsy.net/api/artists/adam-fuss
# edouard-denis-baldus
# https://api.artsy.net/api/artists/edouard-denis-baldus
# man-ray
# https://api.artsy.net/api/artists/man-ray
# henri-cartier-bresson
# https://api.artsy.net/api/artists/henri-cartier-bresson
# daido-moriyama
# https://api.artsy.net/api/artists/daido-moriyama
# berenice-abbott
# https://api.artsy.net/api/artists/berenice-abbott
# walker-evans
# https://api.artsy.net/api/artists/walker-evans
# irving-penn
# https://api.artsy.net/api/artists/irving-penn
# martin-munkácsi
# https://api.artsy.net/api/artists/martin-munkácsi
# error martin-munkácsi
# loretta-lux
# https://api.artsy.net/api/artists/loretta-lux
# mario-giacomelli
# https://api.artsy.net/api/artists/mario-giacomelli
# alvin-langdon-coburn
# https://api.artsy.net/api/artists/alvin-langdon-coburn
# robert-heinecken
# https://api.artsy.net/api/artists/robert-heinecken
# richard-avedon
# https://api.artsy.net/api/artists/richard-avedon
# edward-burtynsky
# https://api.artsy.net/api/artists/edward-burtynsky
# helen-levitt
# https://api.artsy.net/api/artists/helen-levitt
# robert-polidori
# https://api.artsy.net/api/artists/robert-polidori
# mitch-epstein
# https://api.artsy.net/api/artists/mitch-epstein
# robert-adams
# https://api.artsy.net/api/artists/robert-adams
# james-casebere
# https://api.artsy.net/api/artists/james-casebere
# joel-sternfeld
# https://api.artsy.net/api/artists/joel-sternfeld
# harry-callahan
# https://api.artsy.net/api/artists/harry-callahan
# zoe-leonard
# https://api.artsy.net/api/artists/zoe-leonard
# eugene-atget
# https://api.artsy.net/api/artists/eugene-atget
# nicholas-nixon
# https://api.artsy.net/api/artists/nicholas-nixon
# gyorgy-kepes
# https://api.artsy.net/api/artists/gyorgy-kepes
# abelardo-morell
# https://api.artsy.net/api/artists/abelardo-morell
# william-klein
# https://api.artsy.net/api/artists/william-klein
# peter-beard
# https://api.artsy.net/api/artists/peter-beard
# constantin-brancusi
# https://api.artsy.net/api/artists/constantin-brancusi
# bill-brandt
# https://api.artsy.net/api/artists/bill-brandt
# eadweard-muybridge
# https://api.artsy.net/api/artists/eadweard-muybridge
# alfred-eisenstaedt
# https://api.artsy.net/api/artists/alfred-eisenstaedt
# andreas-feininger
# https://api.artsy.net/api/artists/andreas-feininger
# william-eggleston
# https://api.artsy.net/api/artists/william-eggleston
# louise-lawler
# https://api.artsy.net/api/artists/louise-lawler
# bernd-and-hilla-becher
# https://api.artsy.net/api/artists/bernd-and-hilla-becher
# thomas-joshua-cooper
# https://api.artsy.net/api/artists/thomas-joshua-cooper
# horst-p-horst
# https://api.artsy.net/api/artists/horst-p-horst
# victor-schrager
# https://api.artsy.net/api/artists/victor-schrager
# sally-mann
# https://api.artsy.net/api/artists/sally-mann
# emmet-gowin
# https://api.artsy.net/api/artists/emmet-gowin
# frederick-sommer
# https://api.artsy.net/api/artists/frederick-sommer
# nan-goldin
# https://api.artsy.net/api/artists/nan-goldin
# arnold-newman
# https://api.artsy.net/api/artists/arnold-newman
# garry-winogrand
# https://api.artsy.net/api/artists/garry-winogrand
# alfred-stieglitz
# https://api.artsy.net/api/artists/alfred-stieglitz
# lászló-moholy-nagy
# https://api.artsy.net/api/artists/lászló-moholy-nagy
# error lászló-moholy-nagy
# diane-arbus
# https://api.artsy.net/api/artists/diane-arbus
# ansel-adams
# https://api.artsy.net/api/artists/ansel-adams
# chris-mccaw
# https://api.artsy.net/api/artists/chris-mccaw
# pieter-hugo
# https://api.artsy.net/api/artists/pieter-hugo
# gilles-bensimon
# https://api.artsy.net/api/artists/gilles-bensimon
# justin-aversano
# https://api.artsy.net/api/artists/justin-aversano
# anne-w-brigman
# https://api.artsy.net/api/artists/anne-w-brigman
# error anne-w-brigman
# ray-k-metzker
# https://api.artsy.net/api/artists/ray-k-metzker
# sze-tsung-leong
# https://api.artsy.net/api/artists/sze-tsung-leong
# edward-steichen
# https://api.artsy.net/api/artists/edward-steichen
# vera-lutter
# https://api.artsy.net/api/artists/vera-lutter
# candida-höfer
# https://api.artsy.net/api/artists/candida-höfer
# error candida-höfer
# anja-niemi
# https://api.artsy.net/api/artists/anja-niemi
# nick-brandt
# https://api.artsy.net/api/artists/nick-brandt
# lalla-essaydi
# https://api.artsy.net/api/artists/lalla-essaydi
# maurice-tabard
# https://api.artsy.net/api/artists/maurice-tabard
# albert-renger-patzsch
# https://api.artsy.net/api/artists/albert-renger-patzsch
# sharon-harper
# https://api.artsy.net/api/artists/sharon-harper
# danny-lyon
# https://api.artsy.net/api/artists/danny-lyon
# ej-bellocq
# https://api.artsy.net/api/artists/ej-bellocq
# anne-collier
# https://api.artsy.net/api/artists/anne-collier
# bob-thompson
# https://api.artsy.net/api/artists/bob-thompson
# wayne-thiebaud
# https://api.artsy.net/api/artists/wayne-thiebaud
# yayoi-kusama
# https://api.artsy.net/api/artists/yayoi-kusama
# mathias-goeritz
# https://api.artsy.net/api/artists/mathias-goeritz
# victor-vasarely
# https://api.artsy.net/api/artists/victor-vasarely
# laurie-simmons
# https://api.artsy.net/api/artists/laurie-simmons
# wolfgang-tillmans
# https://api.artsy.net/api/artists/wolfgang-tillmans
# hannah-wilke
# https://api.artsy.net/api/artists/hannah-wilke
# beatriz-milhazes
# https://api.artsy.net/api/artists/beatriz-milhazes
# friedel-dzubas
# https://api.artsy.net/api/artists/friedel-dzubas
# jennifer-bartlett
# https://api.artsy.net/api/artists/jennifer-bartlett
# andreas-gursky
# https://api.artsy.net/api/artists/andreas-gursky
# william-baziotes
# https://api.artsy.net/api/artists/william-baziotes
# peter-dreher
# https://api.artsy.net/api/artists/peter-dreher
# janet-fish
# https://api.artsy.net/api/artists/janet-fish
# karel-appel
# https://api.artsy.net/api/artists/karel-appel
# franz-kline
# https://api.artsy.net/api/artists/franz-kline
# ralph-goings
# https://api.artsy.net/api/artists/ralph-goings
# dorothy-fratt
# https://api.artsy.net/api/artists/dorothy-fratt
# chris-ofili
# https://api.artsy.net/api/artists/chris-ofili
# roberto-fabelo
# https://api.artsy.net/api/artists/roberto-fabelo
# larry-poons
# https://api.artsy.net/api/artists/larry-poons
# thomas-downing
# https://api.artsy.net/api/artists/thomas-downing
# lee-ufan
# https://api.artsy.net/api/artists/lee-ufan
# alexander-calder
# https://api.artsy.net/api/artists/alexander-calder
# walasse-ting
# https://api.artsy.net/api/artists/walasse-ting
# jim-dine
# https://api.artsy.net/api/artists/jim-dine
# peter-halley
# https://api.artsy.net/api/artists/peter-halley
# elaine-de-kooning
# https://api.artsy.net/api/artists/elaine-de-kooning
# frank-stella
# https://api.artsy.net/api/artists/frank-stella
# wonder-buhle-mbambo
# https://api.artsy.net/api/artists/wonder-buhle-mbambo
# aboudia
# https://api.artsy.net/api/artists/aboudia
# error aboudia
# erik-parker
# https://api.artsy.net/api/artists/erik-parker
# tomoo-gokita
# https://api.artsy.net/api/artists/tomoo-gokita
# will-boone
# https://api.artsy.net/api/artists/will-boone
# jeff-elrod
# https://api.artsy.net/api/artists/jeff-elrod
# titus-kaphar
# https://api.artsy.net/api/artists/titus-kaphar
# walter-price
# https://api.artsy.net/api/artists/walter-price
# salman-toor
# https://api.artsy.net/api/artists/salman-toor
# tomokazu-matsuyama
# https://api.artsy.net/api/artists/tomokazu-matsuyama
# brent-wadden
# https://api.artsy.net/api/artists/brent-wadden
# manolo-valdes
# https://api.artsy.net/api/artists/manolo-valdes
# jayson-musson
# https://api.artsy.net/api/artists/jayson-musson
# alex-da-corte
# https://api.artsy.net/api/artists/alex-da-corte
# javier-martin
# https://api.artsy.net/api/artists/javier-martin
# richard-lin
# https://api.artsy.net/api/artists/richard-lin
# nina-chanel-abney
# https://api.artsy.net/api/artists/nina-chanel-abney
# jean-baptiste-bernadet
# https://api.artsy.net/api/artists/jean-baptiste-bernadet
# math-bass
# https://api.artsy.net/api/artists/math-bass
# lucien-smith
# https://api.artsy.net/api/artists/lucien-smith
# qin-feng
# https://api.artsy.net/api/artists/qin-feng
# ganesh-pyne
# https://api.artsy.net/api/artists/ganesh-pyne
# mf-husain
# https://api.artsy.net/api/artists/mf-husain
# francis-newton-souza
# https://api.artsy.net/api/artists/francis-newton-souza
# ram-kumar
# https://api.artsy.net/api/artists/ram-kumar
# sadanand-k-bakre
# https://api.artsy.net/api/artists/sadanand-k-bakre
# error sadanand-k-bakre
# anjolie-ela-menon
# https://api.artsy.net/api/artists/anjolie-ela-menon
# bhupen-khakhar
# https://api.artsy.net/api/artists/bhupen-khakhar
# krishen-khanna
# https://api.artsy.net/api/artists/krishen-khanna
# indian-school-bengal-(19)
# https://api.artsy.net/api/artists/indian-school-bengal-(19)
# error indian-school-bengal-(19)
# george-keyt
# https://api.artsy.net/api/artists/george-keyt
# school-of-raja-ravi-varma
# https://api.artsy.net/api/artists/school-of-raja-ravi-varma
# error school-of-raja-ravi-varma
# tyeb-mehta
# https://api.artsy.net/api/artists/tyeb-mehta
# anwar-jalal-shemza
# https://api.artsy.net/api/artists/anwar-jalal-shemza
# ismail-gulgee
# https://api.artsy.net/api/artists/ismail-gulgee
# askari-mian-irani
# https://api.artsy.net/api/artists/askari-mian-irani
# error askari-mian-irani
# gogi-saroj-pal
# https://api.artsy.net/api/artists/gogi-saroj-pal
# sayed-haider-raza
# https://api.artsy.net/api/artists/sayed-haider-raza
# ambadas-khobragade
# https://api.artsy.net/api/artists/ambadas-khobragade
# gulam-rasool-santosh
# https://api.artsy.net/api/artists/gulam-rasool-santosh
# sakti-burman
# https://api.artsy.net/api/artists/sakti-burman
# jamini-roy
# https://api.artsy.net/api/artists/jamini-roy
# jamil-naqsh
# https://api.artsy.net/api/artists/jamil-naqsh
# narayan-shridhar-bendre
# https://api.artsy.net/api/artists/narayan-shridhar-bendre
# error narayan-shridhar-bendre
# bal-chhabda
# https://api.artsy.net/api/artists/bal-chhabda
# sadequain
# https://api.artsy.net/api/artists/sadequain
# mansoor-rahi
# https://api.artsy.net/api/artists/mansoor-rahi
# error mansoor-rahi
# b-prabha
# https://api.artsy.net/api/artists/b-prabha
# jehangir-sabavala
# https://api.artsy.net/api/artists/jehangir-sabavala
# akbar-padamsee
# https://api.artsy.net/api/artists/akbar-padamsee
# nasreen-mohamedi
# https://api.artsy.net/api/artists/nasreen-mohamedi
# hari-ambadas-gade
# https://api.artsy.net/api/artists/hari-ambadas-gade
# satish-gujral
# https://api.artsy.net/api/artists/satish-gujral
# avinash-chandra
# https://api.artsy.net/api/artists/avinash-chandra
# mohammed-kibria
# https://api.artsy.net/api/artists/mohammed-kibria
# error mohammed-kibria
# akkitham-narayanan
# https://api.artsy.net/api/artists/akkitham-narayanan
# laxman-shreshtha
# https://api.artsy.net/api/artists/laxman-shreshtha
# devi-prosad-roy-chowdhury
# https://api.artsy.net/api/artists/devi-prosad-roy-chowdhury
# error devi-prosad-roy-chowdhury
# hokkei
# https://api.artsy.net/api/artists/hokkei
# error hokkei
# maki-bokusen
# https://api.artsy.net/api/artists/maki-bokusen
# error maki-bokusen
# al-souza
# https://api.artsy.net/api/artists/al-souza
# alexander-liberman
# https://api.artsy.net/api/artists/alexander-liberman
# elliott-puckette
# https://api.artsy.net/api/artists/elliott-puckette
# tiffany-studios
# https://api.artsy.net/api/artists/tiffany-studios
# fernando-de-szyszlo
# https://api.artsy.net/api/artists/fernando-de-szyszlo
# rufino-tamayo
# https://api.artsy.net/api/artists/rufino-tamayo
# roberto-montenegro
# https://api.artsy.net/api/artists/roberto-montenegro
# david-alfaro-siqueiros
# https://api.artsy.net/api/artists/david-alfaro-siqueiros
# oswaldo-guayasamin
# https://api.artsy.net/api/artists/oswaldo-guayasamin
# claudio-bravo
# https://api.artsy.net/api/artists/claudio-bravo
# julio-larraz
# https://api.artsy.net/api/artists/julio-larraz
# antonio-segui
# https://api.artsy.net/api/artists/antonio-segui
# cundo-bermúdez
# https://api.artsy.net/api/artists/cundo-bermúdez
# error cundo-bermúdez
# gunther-gerzso
# https://api.artsy.net/api/artists/gunther-gerzso
# alejandro-obregón
# https://api.artsy.net/api/artists/alejandro-obregón
# error alejandro-obregón
# fernando-botero
# https://api.artsy.net/api/artists/fernando-botero
# rodolfo-morales
# https://api.artsy.net/api/artists/rodolfo-morales
# francisco-toledo
# https://api.artsy.net/api/artists/francisco-toledo
# armando-reverón
# https://api.artsy.net/api/artists/armando-reverón
# error armando-reverón
# armando-morales
# https://api.artsy.net/api/artists/armando-morales
# sergio-camargo
# https://api.artsy.net/api/artists/sergio-camargo
# abraham-palatnik
# https://api.artsy.net/api/artists/abraham-palatnik
# julio-galán
# https://api.artsy.net/api/artists/julio-galán
# error julio-galán
# jose-bedia
# https://api.artsy.net/api/artists/jose-bedia
# rene-portocarrero
# https://api.artsy.net/api/artists/rene-portocarrero
# ricardo-martinez
# https://api.artsy.net/api/artists/ricardo-martinez
# juan-soriano
# https://api.artsy.net/api/artists/juan-soriano
# hector-poleo
# https://api.artsy.net/api/artists/hector-poleo
# tomás-sánchez
# https://api.artsy.net/api/artists/tomás-sánchez
# error tomás-sánchez
# guillermo-kuitca
# https://api.artsy.net/api/artists/guillermo-kuitca
# kazuya-sakai
# https://api.artsy.net/api/artists/kazuya-sakai
# oswaldo-vigas
# https://api.artsy.net/api/artists/oswaldo-vigas
# tilsa-tsuchiya
# https://api.artsy.net/api/artists/tilsa-tsuchiya
# arcangelo-ianelli
# https://api.artsy.net/api/artists/arcangelo-ianelli
# eugenio-dittborn
# https://api.artsy.net/api/artists/eugenio-dittborn
# bolivian-school-(18)
# https://api.artsy.net/api/artists/bolivian-school-(18)
# error bolivian-school-(18)
# anonymous-peruvian(18)
# https://api.artsy.net/api/artists/anonymous-peruvian(18)
# error anonymous-peruvian(18)
# eduardo-stupia
# https://api.artsy.net/api/artists/eduardo-stupia
# ecuadorian-school-(18)
# https://api.artsy.net/api/artists/ecuadorian-school-(18)
# error ecuadorian-school-(18)
# anonymous-peruvian-(17)
# https://api.artsy.net/api/artists/anonymous-peruvian-(17)
# error anonymous-peruvian-(17)
# joaquin-torres-garcia
# https://api.artsy.net/api/artists/joaquin-torres-garcia
# geraldo-de-barros
# https://api.artsy.net/api/artists/geraldo-de-barros
# omar-rayo
# https://api.artsy.net/api/artists/omar-rayo
# sarah-grilo
# https://api.artsy.net/api/artists/sarah-grilo
# andean-school-(18)
# https://api.artsy.net/api/artists/andean-school-(18)
# error andean-school-(18)
# anonymous-mexican-(17/18)
# https://api.artsy.net/api/artists/anonymous-mexican-(17/18)
# error anonymous-mexican-(17/18)
# peruvian-school-cuzco-(18)
# https://api.artsy.net/api/artists/peruvian-school-cuzco-(18)
# error peruvian-school-cuzco-(18)
# peruvian-school-cuzco-(17/18)
# https://api.artsy.net/api/artists/peruvian-school-cuzco-(17/18)
# error peruvian-school-cuzco-(17/18)
# mexican-school-(18)
# https://api.artsy.net/api/artists/mexican-school-(18)
# error mexican-school-(18)
# roberto-obregón
# https://api.artsy.net/api/artists/roberto-obregón
# error roberto-obregón
# rómulo-macció
# https://api.artsy.net/api/artists/rómulo-macció
# error rómulo-macció
# rockwell-kent
# https://api.artsy.net/api/artists/rockwell-kent
# sanford-robinson-gifford
# https://api.artsy.net/api/artists/sanford-robinson-gifford
# norman-rockwell
# https://api.artsy.net/api/artists/norman-rockwell
# abbott-fuller-graves
# https://api.artsy.net/api/artists/abbott-fuller-graves
# theodore-robinson
# https://api.artsy.net/api/artists/theodore-robinson
# alfred-henry-maurer
# https://api.artsy.net/api/artists/alfred-henry-maurer
# error alfred-henry-maurer
# victor-william-higgins
# https://api.artsy.net/api/artists/victor-william-higgins
# error victor-william-higgins
# samuel-s-carr
# https://api.artsy.net/api/artists/samuel-s-carr
# william-glackens
# https://api.artsy.net/api/artists/william-glackens
# error william-glackens
# thomas-hill
# https://api.artsy.net/api/artists/thomas-hill
# charles-wimar
# https://api.artsy.net/api/artists/charles-wimar
# error charles-wimar
# albert-bierstadt
# https://api.artsy.net/api/artists/albert-bierstadt
# eastman-johnson
# https://api.artsy.net/api/artists/eastman-johnson
# john-frederick-peto
# https://api.artsy.net/api/artists/john-frederick-peto
# thomas-moran
# https://api.artsy.net/api/artists/thomas-moran
# joseph-henry-sharp
# https://api.artsy.net/api/artists/joseph-henry-sharp
# emily-mason
# https://api.artsy.net/api/artists/emily-mason
# rackstraw-downes
# https://api.artsy.net/api/artists/rackstraw-downes
# ellen-altfest
# https://api.artsy.net/api/artists/ellen-altfest
# john-singer-sargent
# https://api.artsy.net/api/artists/john-singer-sargent
# max-kuehne
# https://api.artsy.net/api/artists/max-kuehne
# jackson-pollock
# https://api.artsy.net/api/artists/jackson-pollock
# guy-pene-du-bois
# https://api.artsy.net/api/artists/guy-pene-du-bois
# alfred-thompson-bricher
# https://api.artsy.net/api/artists/alfred-thompson-bricher
# gerald-cassidy
# https://api.artsy.net/api/artists/gerald-cassidy
# john-frederick-kensett
# https://api.artsy.net/api/artists/john-frederick-kensett
# jasper-francis-cropsey
# https://api.artsy.net/api/artists/jasper-francis-cropsey
# jan-müller
# https://api.artsy.net/api/artists/jan-müller
# error jan-müller
# georgia-o'keeffe
# https://api.artsy.net/api/artists/georgia-o'keeffe
# error georgia-o'keeffe
# john-koch
# https://api.artsy.net/api/artists/john-koch
# john-george-brown
# https://api.artsy.net/api/artists/john-george-brown
# william-mcgregor-paxton
# https://api.artsy.net/api/artists/william-mcgregor-paxton
# robert-riggs
# https://api.artsy.net/api/artists/robert-riggs
# martin-johnson-heade
# https://api.artsy.net/api/artists/martin-johnson-heade
# asher-brown-durand
# https://api.artsy.net/api/artists/asher-brown-durand
# george-inness
# https://api.artsy.net/api/artists/george-inness
# george-cochran-lambdin
# https://api.artsy.net/api/artists/george-cochran-lambdin
# joseph-christian-leyendecker
# https://api.artsy.net/api/artists/joseph-christian-leyendecker
# frank-earle-schoonover
# https://api.artsy.net/api/artists/frank-earle-schoonover
# edward-henry-potthast
# https://api.artsy.net/api/artists/edward-henry-potthast
# edwin-dickinson
# https://api.artsy.net/api/artists/edwin-dickinson
# pat-steir
# https://api.artsy.net/api/artists/pat-steir
# richard-anuszkiewicz
# https://api.artsy.net/api/artists/richard-anuszkiewicz
# roy-lichtenstein
# https://api.artsy.net/api/artists/roy-lichtenstein
# ilya-bolotowsky
# https://api.artsy.net/api/artists/ilya-bolotowsky
# conrad-marca-relli
# https://api.artsy.net/api/artists/conrad-marca-relli
# susan-rothenberg
# https://api.artsy.net/api/artists/susan-rothenberg
# yvonne-thomas
# https://api.artsy.net/api/artists/yvonne-thomas
# john-wesley
# https://api.artsy.net/api/artists/john-wesley
# douglas-gordon
# https://api.artsy.net/api/artists/douglas-gordon
# jesús-rafael-soto
# https://api.artsy.net/api/artists/jesús-rafael-soto
# error jesús-rafael-soto
# thomas-struth
# https://api.artsy.net/api/artists/thomas-struth
# neil-jenney
# https://api.artsy.net/api/artists/neil-jenney
# jules-pascin
# https://api.artsy.net/api/artists/jules-pascin
# georges-valmier
# https://api.artsy.net/api/artists/georges-valmier
# auguste-herbin
# https://api.artsy.net/api/artists/auguste-herbin
# emile-bernard
# https://api.artsy.net/api/artists/emile-bernard
# beauford-delaney
# https://api.artsy.net/api/artists/beauford-delaney
# frederick-hammersley
# https://api.artsy.net/api/artists/frederick-hammersley
# john-mclaughlin
# https://api.artsy.net/api/artists/john-mclaughlin
# robert-motherwell
# https://api.artsy.net/api/artists/robert-motherwell
# mark-tansey
# https://api.artsy.net/api/artists/mark-tansey
# carl-andre
# https://api.artsy.net/api/artists/carl-andre
# martin-wong
# ...
# https://api.artsy.net/api/artists/cavaliere-giovanni-baglione
# error cavaliere-giovanni-baglione
# jacopo-bellini
# https://api.artsy.net/api/artists/jacopo-bellini
# hans-hoffmann
# https://api.artsy.net/api/artists/hans-hoffmann
# studio-of-dieric-bouts-the-elder
# https://api.artsy.net/api/artists/studio-of-dieric-bouts-the-elder
# error studio-of-dieric-bouts-the-elder
# sebastiano-ricci
# https://api.artsy.net/api/artists/sebastiano-ricci
# gaetano-gandolfi
# https://api.artsy.net/api/artists/gaetano-gandolfi
# jean-françois-de-troy
# https://api.artsy.net/api/artists/jean-françois-de-troy
# error jean-françois-de-troy
# francesco-guardi
# https://api.artsy.net/api/artists/francesco-guardi
# follower-of-hieronymus-bosch
# https://api.artsy.net/api/artists/follower-of-hieronymus-bosch
# giulio-romano
# https://api.artsy.net/api/artists/giulio-romano
# guercino
# https://api.artsy.net/api/artists/guercino
# girolamo-mazzola-bedoli
# https://api.artsy.net/api/artists/girolamo-mazzola-bedoli
# error girolamo-mazzola-bedoli
# gysbert-gillisz-de-hondecoeter
# https://api.artsy.net/api/artists/gysbert-gillisz-de-hondecoeter
# error gysbert-gillisz-de-hondecoeter
# carl-spitzweg
# https://api.artsy.net/api/artists/carl-spitzweg
# giovanni-boldini
# https://api.artsy.net/api/artists/giovanni-boldini
# hendrik-reekers
# https://api.artsy.net/api/artists/hendrik-reekers
# error hendrik-reekers
# philip-wilson-steer
# https://api.artsy.net/api/artists/philip-wilson-steer
# john-collier
# https://api.artsy.net/api/artists/john-collier
# joaquin-sorolla
# https://api.artsy.net/api/artists/joaquin-sorolla
# error joaquin-sorolla
# jean-beraud
# https://api.artsy.net/api/artists/jean-beraud
# hendrik-willem-mesdag
# https://api.artsy.net/api/artists/hendrik-willem-mesdag
# sir-george-clausen
# https://api.artsy.net/api/artists/sir-george-clausen
# error sir-george-clausen
# pierre-reymond
# https://api.artsy.net/api/artists/pierre-reymond
# error pierre-reymond
# cristóbal-de-villalpando
# https://api.artsy.net/api/artists/cristóbal-de-villalpando
# error cristóbal-de-villalpando
# giovanni-benedetto-castiglione
# https://api.artsy.net/api/artists/giovanni-benedetto-castiglione
# bonifazio-de-pitati
# https://api.artsy.net/api/artists/bonifazio-de-pitati
# error bonifazio-de-pitati
# donato-creti
# https://api.artsy.net/api/artists/donato-creti
# charles-françois-daubigny
# https://api.artsy.net/api/artists/charles-françois-daubigny
# error charles-françois-daubigny
# alphonse-mucha
# https://api.artsy.net/api/artists/alphonse-mucha
# antoine-caron
# https://api.artsy.net/api/artists/antoine-caron
# pieter-aertsen
# https://api.artsy.net/api/artists/pieter-aertsen
# error pieter-aertsen
# govaert-flinck
# https://api.artsy.net/api/artists/govaert-flinck
# balthasar-van-der-ast
# https://api.artsy.net/api/artists/balthasar-van-der-ast
# johan-moreelse
# https://api.artsy.net/api/artists/johan-moreelse
# error johan-moreelse
# bernardino-di-bosio-zaganelli
# https://api.artsy.net/api/artists/bernardino-di-bosio-zaganelli
# error bernardino-di-bosio-zaganelli
# françois-boucher
# https://api.artsy.net/api/artists/françois-boucher
# error françois-boucher
# julio-romero-de-torres
# https://api.artsy.net/api/artists/julio-romero-de-torres
# error julio-romero-de-torres
# donato-de'-bardi
# https://api.artsy.net/api/artists/donato-de'-bardi
# error donato-de'-bardi
# michel-lambert
# https://api.artsy.net/api/artists/michel-lambert
# error michel-lambert
# pieter-de-neyn
# https://api.artsy.net/api/artists/pieter-de-neyn
# error pieter-de-neyn
# jan-steen
# https://api.artsy.net/api/artists/jan-steen
# error jan-steen
# jan-van-de-cappelle
# https://api.artsy.net/api/artists/jan-van-de-cappelle
# emile-jean-horace-vernet
# https://api.artsy.net/api/artists/emile-jean-horace-vernet
# error emile-jean-horace-vernet
# jean-leon-gerôme
# https://api.artsy.net/api/artists/jean-leon-gerôme
# error jean-leon-gerôme
# alfred-stevens
# https://api.artsy.net/api/artists/alfred-stevens
# edouard-henri-theophile-pingret
# https://api.artsy.net/api/artists/edouard-henri-theophile-pingret
# theodore-chasseriau
# https://api.artsy.net/api/artists/theodore-chasseriau
# françois-clouet
# https://api.artsy.net/api/artists/françois-clouet
# error françois-clouet
# jean-baptiste-leprince
# https://api.artsy.net/api/artists/jean-baptiste-leprince
# error jean-baptiste-leprince
# jean-auguste-dominique-ingres
# https://api.artsy.net/api/artists/jean-auguste-dominique-ingres
# nicolas-antoine-taunay
# https://api.artsy.net/api/artists/nicolas-antoine-taunay
# chinese-school-(19)
# https://api.artsy.net/api/artists/chinese-school-(19)
# error chinese-school-(19)
# albert-lebourg
# https://api.artsy.net/api/artists/albert-lebourg
# max-liebermann
# https://api.artsy.net/api/artists/max-liebermann
# albert-bloch
# https://api.artsy.net/api/artists/albert-bloch
# carlos-nadal
# https://api.artsy.net/api/artists/carlos-nadal
# takanori-ogisu
# https://api.artsy.net/api/artists/takanori-ogisu
# error takanori-ogisu
# edgar-degas
# https://api.artsy.net/api/artists/edgar-degas
# charles-camoin
# https://api.artsy.net/api/artists/charles-camoin
# lisa-yuskavage
# https://api.artsy.net/api/artists/lisa-yuskavage
# milton-resnick
# https://api.artsy.net/api/artists/milton-resnick
# sandro-chia
# https://api.artsy.net/api/artists/sandro-chia
# mimmo-paladino
# https://api.artsy.net/api/artists/mimmo-paladino
# michael-(corinne)-west
# https://api.artsy.net/api/artists/michael-(corinne)-west
# error michael-(corinne)-west
# stanley-boxer
# https://api.artsy.net/api/artists/stanley-boxer
# robert-longo
# https://api.artsy.net/api/artists/robert-longo
# elizabeth-murray
# https://api.artsy.net/api/artists/elizabeth-murray
# mary-heilmann
# https://api.artsy.net/api/artists/mary-heilmann
# agostino-bonalumi
# https://api.artsy.net/api/artists/agostino-bonalumi
# antoni-tàpies
# https://api.artsy.net/api/artists/antoni-tàpies
# error antoni-tàpies
# miquel-barceló
# https://api.artsy.net/api/artists/miquel-barceló
# error miquel-barceló
# frank-thiel
# https://api.artsy.net/api/artists/frank-thiel
# christopher-williams
# https://api.artsy.net/api/artists/christopher-williams
# gabriel-orozco
# https://api.artsy.net/api/artists/gabriel-orozco
# gilbert-and-george
# https://api.artsy.net/api/artists/gilbert-and-george
# philip-pearlstein
# https://api.artsy.net/api/artists/philip-pearlstein
# enrico-castellani
# https://api.artsy.net/api/artists/enrico-castellani
# david-reed
# https://api.artsy.net/api/artists/david-reed
# peter-schuyff
# https://api.artsy.net/api/artists/peter-schuyff
# william-t-wiley
# https://api.artsy.net/api/artists/william-t-wiley
# wojciech-fangor
# https://api.artsy.net/api/artists/wojciech-fangor
# austyn-weiner
# https://api.artsy.net/api/artists/austyn-weiner
# petra-cortright
# https://api.artsy.net/api/artists/petra-cortright
# sadie-benning
# https://api.artsy.net/api/artists/sadie-benning
# carla-klein
# https://api.artsy.net/api/artists/carla-klein
# julia-chiang
# https://api.artsy.net/api/artists/julia-chiang
# jorge-de-la-vega
# https://api.artsy.net/api/artists/jorge-de-la-vega
# nicolas-carone
# https://api.artsy.net/api/artists/nicolas-carone
# robert-alice
# https://api.artsy.net/api/artists/robert-alice
# error robert-alice
# cy-gavin
# https://api.artsy.net/api/artists/cy-gavin
# danh-vo
# https://api.artsy.net/api/artists/danh-vo
# leelee-kimmel
# https://api.artsy.net/api/artists/leelee-kimmel
# seth-price
# https://api.artsy.net/api/artists/seth-price
# janet-taylor-pickett
# https://api.artsy.net/api/artists/janet-taylor-pickett
# jenna-gribbon
# https://api.artsy.net/api/artists/jenna-gribbon
# tamara-de-lempicka
# https://api.artsy.net/api/artists/tamara-de-lempicka
# jasper-johns
# https://api.artsy.net/api/artists/jasper-johns
# paul-klee
# https://api.artsy.net/api/artists/paul-klee
# emil-nolde
# https://api.artsy.net/api/artists/emil-nolde
# rene-magritte
# https://api.artsy.net/api/artists/rene-magritte
# leng-mei
# https://api.artsy.net/api/artists/leng-mei
# suzuki-kiitsu
# https://api.artsy.net/api/artists/suzuki-kiitsu
# sakai-hoitsu
# https://api.artsy.net/api/artists/sakai-hoitsu
# nalini-malani
# https://api.artsy.net/api/artists/nalini-malani
# walter-langhammer
# https://api.artsy.net/api/artists/walter-langhammer
# b-vithal
# https://api.artsy.net/api/artists/b-vithal
# allah-bux
# https://api.artsy.net/api/artists/allah-bux
# error allah-bux
# vasudeo-s-gaitonde
# https://api.artsy.net/api/artists/vasudeo-s-gaitonde
# ramkinkar-baij
# https://api.artsy.net/api/artists/ramkinkar-baij
# raghu-rai
# https://api.artsy.net/api/artists/raghu-rai
# prokash-karmakar
# https://api.artsy.net/api/artists/prokash-karmakar
# bikash-bhattacharjee
# https://api.artsy.net/api/artists/bikash-bhattacharjee
# attingal-ramachandran
# https://api.artsy.net/api/artists/attingal-ramachandran
# error attingal-ramachandran
# badhan-das
# https://api.artsy.net/api/artists/badhan-das
# error badhan-das
# hemen-mazumdar
# https://api.artsy.net/api/artists/hemen-mazumdar
# rabin-mondal
# https://api.artsy.net/api/artists/rabin-mondal
# hiroshi-yoshida
# https://api.artsy.net/api/artists/hiroshi-yoshida
# error hiroshi-yoshida
# kawanabe-kyosai
# https://api.artsy.net/api/artists/kawanabe-kyosai
# utagawa-hiroshige
# https://api.artsy.net/api/artists/utagawa-hiroshige
# error utagawa-hiroshige
# anonymous-korean-(17)
# https://api.artsy.net/api/artists/anonymous-korean-(17)
# error anonymous-korean-(17)
# nagasawa-rosetsu
# https://api.artsy.net/api/artists/nagasawa-rosetsu
# maruyama-oshin
# https://api.artsy.net/api/artists/maruyama-oshin
# error maruyama-oshin
# kokuta-suda
# https://api.artsy.net/api/artists/kokuta-suda
# circle-of-kim-hongdo
# https://api.artsy.net/api/artists/circle-of-kim-hongdo
# error circle-of-kim-hongdo
# mario-carreño
# https://api.artsy.net/api/artists/mario-carreño
# error mario-carreño
# carlos-cruz-diez
# https://api.artsy.net/api/artists/carlos-cruz-diez
# amelia-peláez
# https://api.artsy.net/api/artists/amelia-peláez
# error amelia-peláez
# ana-mercedes-hoyos
# https://api.artsy.net/api/artists/ana-mercedes-hoyos
# leonora-carrington
# https://api.artsy.net/api/artists/leonora-carrington
# alfredo-ramos-martinez
# https://api.artsy.net/api/artists/alfredo-ramos-martinez
# zilia-sanchez
# https://api.artsy.net/api/artists/zilia-sanchez
# olga-de-amaral
# https://api.artsy.net/api/artists/olga-de-amaral
# diego-rivera
# https://api.artsy.net/api/artists/diego-rivera
# eduardo-kingman
# https://api.artsy.net/api/artists/eduardo-kingman
# jose-chávez-morado
# https://api.artsy.net/api/artists/jose-chávez-morado
# error jose-chávez-morado
# olga-albizu
# https://api.artsy.net/api/artists/olga-albizu
# peruvian-school-(18)
# https://api.artsy.net/api/artists/peruvian-school-(18)
# error peruvian-school-(18)
# carmen-herrera
# https://api.artsy.net/api/artists/carmen-herrera
# alice-rahon
# https://api.artsy.net/api/artists/alice-rahon
# lilia-carrillo
# https://api.artsy.net/api/artists/lilia-carrillo
# arnaldo-roche-rabell
# https://api.artsy.net/api/artists/arnaldo-roche-rabell
# mercedes-pardo
# https://api.artsy.net/api/artists/mercedes-pardo
# sebastian-salcedo
# https://api.artsy.net/api/artists/sebastian-salcedo
# jose-gurvich
# https://api.artsy.net/api/artists/jose-gurvich
# luis-de-riaño
# https://api.artsy.net/api/artists/luis-de-riaño
# error luis-de-riaño
# chuck-close
# https://api.artsy.net/api/artists/chuck-close
# carrie-mae-weems
# https://api.artsy.net/api/artists/carrie-mae-weems
# eric-fischl
# https://api.artsy.net/api/artists/eric-fischl
# marilyn-minter
# https://api.artsy.net/api/artists/marilyn-minter
# thomas-demand
# https://api.artsy.net/api/artists/thomas-demand
# donald-baechler
# https://api.artsy.net/api/artists/donald-baechler
# neo-rauch
# https://api.artsy.net/api/artists/neo-rauch
# doris-salcedo
# https://api.artsy.net/api/artists/doris-salcedo
# brice-marden
# https://api.artsy.net/api/artists/brice-marden
# barnett-newman
# https://api.artsy.net/api/artists/barnett-newman
# chris-page
# https://api.artsy.net/api/artists/chris-page
# alfonso-ossorio
# https://api.artsy.net/api/artists/alfonso-ossorio
# rh-quaytman
# https://api.artsy.net/api/artists/rh-quaytman
# spencer-sweeney
# https://api.artsy.net/api/artists/spencer-sweeney
# theo-van-rysselberghe
# https://api.artsy.net/api/artists/theo-van-rysselberghe
# alma-thomas
# https://api.artsy.net/api/artists/alma-thomas
# john-baeder
# https://api.artsy.net/api/artists/john-baeder
# karin-davie
# https://api.artsy.net/api/artists/karin-davie
# roger-brown
# https://api.artsy.net/api/artists/roger-brown
# esteban-vicente
# https://api.artsy.net/api/artists/esteban-vicente
# joan-semmel
# https://api.artsy.net/api/artists/joan-semmel
# allan-d'arcangelo
# https://api.artsy.net/api/artists/allan-d'arcangelo
# error allan-d'arcangelo
# bruce-conner
# https://api.artsy.net/api/artists/bruce-conner
# mel-ramos
# https://api.artsy.net/api/artists/mel-ramos
# richard-hambleton
# https://api.artsy.net/api/artists/richard-hambleton
# eric-freeman
# https://api.artsy.net/api/artists/eric-freeman
# charles-white
# https://api.artsy.net/api/artists/charles-white
# error charles-white
# terry-winters
# https://api.artsy.net/api/artists/terry-winters
# john-sonsini
# https://api.artsy.net/api/artists/john-sonsini
# ed-paschke
# https://api.artsy.net/api/artists/ed-paschke
# katherine-bradford
# https://api.artsy.net/api/artists/katherine-bradford
# error katherine-bradford
# donald-roller-wilson
# https://api.artsy.net/api/artists/donald-roller-wilson
# robert-indiana
# https://api.artsy.net/api/artists/robert-indiana
# derek-fordjour
# https://api.artsy.net/api/artists/derek-fordjour
# barry-mcgee
# https://api.artsy.net/api/artists/barry-mcgee
# roxy-paine
# https://api.artsy.net/api/artists/roxy-paine
# christo
# https://api.artsy.net/api/artists/christo
# tadasuke-kuwayama-(tadasky)
# https://api.artsy.net/api/artists/tadasuke-kuwayama-(tadasky)
# error tadasuke-kuwayama-(tadasky)
# nathaniel-mary-quinn
# https://api.artsy.net/api/artists/nathaniel-mary-quinn
# elizabeth-neel
# https://api.artsy.net/api/artists/elizabeth-neel
# adam-pendleton
# https://api.artsy.net/api/artists/adam-pendleton
# xylor-jane
# https://api.artsy.net/api/artists/xylor-jane
# paul-pfeiffer
# https://api.artsy.net/api/artists/paul-pfeiffer
# yinka-shonibare-cbe
# https://api.artsy.net/api/artists/yinka-shonibare-cbe
# makoto-saito
# https://api.artsy.net/api/artists/makoto-saito
# charles-arnoldi
# https://api.artsy.net/api/artists/charles-arnoldi
# error charles-arnoldi
# secundino-hernández
# https://api.artsy.net/api/artists/secundino-hernández
# error secundino-hernández
# tauba-auerbach
# https://api.artsy.net/api/artists/tauba-auerbach
# adam-mcewen
# https://api.artsy.net/api/artists/adam-mcewen
# edward-hicks
# https://api.artsy.net/api/artists/edward-hicks
# john-stobart
# https://api.artsy.net/api/artists/john-stobart
# charles-wysocki
# https://api.artsy.net/api/artists/charles-wysocki
# james-walker
# https://api.artsy.net/api/artists/james-walker
# error james-walker
# school-of-john-smibert
# https://api.artsy.net/api/artists/school-of-john-smibert
# error school-of-john-smibert
# noah-north
# https://api.artsy.net/api/artists/noah-north
# error noah-north
# sheldon-peck
# https://api.artsy.net/api/artists/sheldon-peck
# error sheldon-peck
# benjamin-west
# https://api.artsy.net/api/artists/benjamin-west
# school-of-robert-feke
# https://api.artsy.net/api/artists/school-of-robert-feke
# error school-of-robert-feke
# winthrop-chandler
# https://api.artsy.net/api/artists/winthrop-chandler
# jacob-j-kass
# https://api.artsy.net/api/artists/jacob-j-kass
# error jacob-j-kass
# samuel-p-howes
# https://api.artsy.net/api/artists/samuel-p-howes
# error samuel-p-howes
# benjamin-franklin-reinhart
# https://api.artsy.net/api/artists/benjamin-franklin-reinhart
# error benjamin-franklin-reinhart
# augustin-lesage
# https://api.artsy.net/api/artists/augustin-lesage
# earl-cunningham
# https://api.artsy.net/api/artists/earl-cunningham
# error earl-cunningham
# bruno-del-favero
# https://api.artsy.net/api/artists/bruno-del-favero
# error bruno-del-favero
# jon-serl
# https://api.artsy.net/api/artists/jon-serl
# justin-mccarthy
# https://api.artsy.net/api/artists/justin-mccarthy
# amos-ferguson
# https://api.artsy.net/api/artists/amos-ferguson
# sister-gertrude-morgan
# https://api.artsy.net/api/artists/sister-gertrude-morgan
# james-castle
# https://api.artsy.net/api/artists/james-castle
# leroy-almon
# https://api.artsy.net/api/artists/leroy-almon
# helen-lafrance
# https://api.artsy.net/api/artists/helen-lafrance
# milard-c-hunt
# https://api.artsy.net/api/artists/milard-c-hunt
# error milard-c-hunt
# rosie-lee-light
# https://api.artsy.net/api/artists/rosie-lee-light
# error rosie-lee-light

# %%
# create dict with artist info to dataframe 
new = pd.DataFrame.from_dict(case_list)
new
# Out:
#                        artist  gender nationality birthday  \
# 0          thomas-hart-benton    male    American     1889
# 1                dale-nichols    male    American     1904
# 2                milton-avery    male    American     1885
# 3    stanton-macdonald-wright    male    American     1890
# 4            fairfield-porter    male    American     1907
# ..                        ...     ...         ...      ...
# 970             amos-ferguson    male    Bahamian     1920
# 971    sister-gertrude-morgan  female    American     1900
# 972              james-castle    male    American     1899
# 973               leroy-almon    male    American     1938
# 974            helen-lafrance  female    American     1919
#
#                                hometown
# 0                      Neosho, Missouri
# 1         David City, NE, United States
# 2                      Altmar, New York
# 3    Charlottesville, VA, United States
# 4               Winnetka, Illinois, USA
# ..                                  ...
# 970                  Exuma, The Bahamas
# 971                 La Fayette, AL, USA
# 972              Garden Valley, ID, USA
# 973                 Tallapoosa, GA, USA
# 974        Graves County, Kentucky, USA
#
# [975 rows x 5 columns]

# %%
#merge artist info with artnet dataframe. save file 
pd.merge(df,new,on='artist',how='inner')
# Out:
#                         name                                title  \
# 0         Thomas Hart Benton                 Keith Farm, Chilmark
# 1         Thomas Hart Benton              Study for 'Lumber Mill'
# 2         Thomas Hart Benton  Study for 'The Lord is My Shepherd'
# 3         Thomas Hart Benton                   Study for 'Traders
# 4         Thomas Hart Benton     Study for 'The History of Water'
# ...                      ...                                  ...
# 2417  Sister Gertrude Morgan                  Let's Make A Record
# 2418            James Castle  Untitled (Interior with Two Chairs)
# 2419            James Castle     Untitled (Female Figure in Coat)
# 2420             Leroy Almon                  Television Ministry
# 2421          Helen LaFrance                         Steeplechase
#
#                                                  medium  \
# 0                                         oil on canvas
# 1                        oil en grisaille on paperboard
# 2                                         oil on canvas
# 3                                     oil on paperboard
# 4                              tempera on gessoed board
# ...                                                 ...
# 2417           acrylic and ink on printed record sleeve
# 2418  soot and spit on repurposed National Life and ...
# 2419  colored pulp and soot and spit on reverse of r...
# 2420            metallic and matte paint on carved wood
# 2421                                      oil on canvas
#
#                                                    year  \
# 0                                                  1955
# 1                                            Circa 1928
# 2                                            Circa 1926
# 3                                            Circa 1924
# 4                                       Circa 1930-1931
# ...                                                 ...
# 2417  Height 12.3 in.; Width 12.4 in. / Height 31.1 ...
# 2418  Height 6.9 in.; Width 8.4 in. / Height 17.5 cm...
# 2419  Height 6.8 in.; Width 4.9 in. / Height 17.2 cm...
# 2420                                               1987
# 2421                                               1997
#
#                                                    size  \
# 0     Height 21 in.; Width 29 in. / Height 53.3 cm.;...
# 1     Height 8.5 in.; Width 11.6 in. / Height 21.6 c...
# 2     Height 8.5 in.; Width 6.6 in. / Height 21.6 cm...
# 3     Height 8 in.; Width 8.7 in. / Height 20.3 cm.;...
# 4     Height 17.8 in.; Width 14.3 in. / Height 45.1 ...
# ...                                                 ...
# 2417  Christie's New York: Friday, January 17, 2020 ...
# 2418                                             Signed
# 2419  Christie's New York: Friday, January 17, 2020 ...
# 2420  Height 10.3 in.; Width 24.5 in. / Height 26 cm...
# 2421  Height 17.5 in.; Width 35.5 in. / Height 44.4 ...
#
#                                                    sale  \
# 0     Christie's New York: Thursday, November 18, 20...
# 1     Christie's New York: Tuesday, May 18, 2021 [Lo...
# 2                                 20,000 - 30,000 USD ?
# 3     Christie's New York: Tuesday, May 18, 2021 [Lo...
# 4     Christie's New York: Wednesday, October 28, 20...
# ...                                                 ...
# 2417                                5,625 USD Premium ?
# 2418                                6,000 - 8,000 USD ?
# 2419                                5,625 USD Premium ?
# 2420  Christie's New York: Friday, January 17, 2020 ...
# 2421                                1,000 - 2,000 USD ?
#
#                        sold                     estimate  \
# 0     4,830,000 USD Premium  2,000,000 - 3,000,000 USD ?
# 1        32,500 USD Premium        30,000 - 50,000 USD ?
# 2                       NaN                    Bought In
# 3                 Bought In       70,000 - 100,000 USD ?
# 4        68,750 USD Premium       80,000 - 120,000 USD ?
# ...                     ...                          ...
# 2417                    NaN                          NaN
# 2418                    NaN          8,125 USD Premium ?
# 2419                    NaN                          NaN
# 2420      1,000 USD Premium            700 - 1,000 USD ?
# 2421                    NaN          1,000 USD Premium ?
#
#                       artist  gender nationality birthday  \
# 0         thomas-hart-benton    male    American     1889
# 1         thomas-hart-benton    male    American     1889
# 2         thomas-hart-benton    male    American     1889
# 3         thomas-hart-benton    male    American     1889
# 4         thomas-hart-benton    male    American     1889
# ...                      ...     ...         ...      ...
# 2417  sister-gertrude-morgan  female    American     1900
# 2418            james-castle    male    American     1899
# 2419            james-castle    male    American     1899
# 2420             leroy-almon    male    American     1938
# 2421          helen-lafrance  female    American     1919
#
#                           hometown
# 0                 Neosho, Missouri
# 1                 Neosho, Missouri
# 2                 Neosho, Missouri
# 3                 Neosho, Missouri
# 4                 Neosho, Missouri
# ...                            ...
# 2417           La Fayette, AL, USA
# 2418        Garden Valley, ID, USA
# 2419        Garden Valley, ID, USA
# 2420           Tallapoosa, GA, USA
# 2421  Graves County, Kentucky, USA
#
# [2422 rows x 13 columns]
